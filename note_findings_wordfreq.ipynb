# %% [markdown]
# - get most frequent/interesting phrases from chf cohort reports

# %%
import sys
sys.path.append("../../notebooks")

import utils
utils.jpt_autoreload()
utils.jpt_full_width()
utils.jpt_suppress_warnings()
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import os, re, time
import pandas as pd
import numpy as np

from label_reports import get_chf_cohort, label_report
import negex
from regex_utils import WordMatch
from section_parser import section_text
from extract_findings import extract_findings

from tabulate import tabulate
from pprint import pprint

from datasets import MimicCxrLabels, MimicCxrReader, MimicCxrBase

# %%
cxr_reader = MimicCxrReader()
cxr_labels = MimicCxrLabels()
cxr_base = MimicCxrBase()

# %%
keywords = [ 
    'acute cardiopulmonary process',
    'focal consolidation',
    'pleural effusion',
    'pneumothorax',
    'nodular opacities',
    'pneumonia'
]
# Out:
# [('acute cardiopulmonary process', 0.0),
#  ('focal consolidation', 0.0),
#  ('pleural effusion', 0.0),
#  ('pneumothorax', 0.0),
#  ('nodular opacities', 1.0),
#  ('pneumonia', nan)]

# %%
cohort = 'chf'
current_path = '.'
chf_metadata_path = os.path.join(
    current_path, 'mimic_cxr_heart_failure', 'mimic_cxr_metadata_hf.tsv')

if cohort == 'all':
    meta_df = MimicCxrBase().get_meta_df()
    study_ids = meta_df['study_id'].unique()
else:
    meta_df = pd.read_csv(chf_metadata_path, sep='\t')
    meta_df = meta_df[meta_df['heart_failure'] == 1]
    study_ids = meta_df['study_id'].unique()

# %%
# study_id = 54577367
# report = cxr_reader.get_report(study_id)

# def section_finding(report):
#     sections, section_names, section_idx = section_text(report)
#     if 'findings' in section_names:
#         ind = section_names.index('findings')
#         return sections[ind]
#     else:
#         ""
# section = section_finding(report)

# data = {}
# data[study_id] = section

# df = pd.DataFrame.from_dict(data, columns=['findings'],orient='index')
# df

# %%
gen_findings_text = False
findings_df_path = f'note_findings_wordfreq_findings_{cohort}_df'

if gen_findings_text:

    data = {}

    start = time.time()
    for i, study_id in enumerate(study_ids):

        try:
            report = cxr_reader.get_report(study_id)
            section = section_finding(report)
            data[study_id] = section
        except:
            continue

        if i%1000 == 0:
            end = time.time()
            print(f'Iter={i}\tTime Elapsed={end-start:.3f}')
            start = time.time()


    df = pd.DataFrame.from_dict(data, columns=['findings'],orient='index')
    df.to_csv(findings_df_path, index=True)
    print(len(df))
    print(f'write to {findings_df_path}')
else:
    df = pd.read_csv(findings_df_path, index_col=0)

df['study_id'] = df.index
df = df.reset_index(drop=True)

# %%
edema_df = cxr_base.get_edema_df()
edema_df
# Out:
#       study_id                                      dicom_id  subject_id  \
# 0     54577367  cfb03587-782edf6c-1bf392e1-98196cd5-365d69e8  10000980.0
# 1     54980801  a75a1fbe-802065ad-717eb7c1-e2ce3552-646276a6  10000980.0
# 2     59988438  925b9496-a956d7b2-05185e52-bb33313b-c06ee522  10000980.0
# 3     50109051  57dbb610-aad7676f-da4741ea-db34ef0e-773492f3  10011938.0
# 4     51895247  bf724128-9131f33a-6fd065d5-19041750-9e7f8707  10011938.0
# ...        ...                                           ...         ...
# 7519  58763598  7bdf562a-8945bd11-382bb25a-36306d5b-4c1f31f5  19997367.0
# 7521  59159686  a06c18fa-0be7ccf1-5b99ff5c-429949f2-86361e99  19997367.0
# 7522  54878259  a0312c46-db145040-b7bc5dc0-7bf8a213-393a3ab3  19998330.0
# 7523  59281793  b7fea537-87829311-389dc1c3-0947f202-bcf5f743  19998330.0
# 7524  59694089  fb10d1e3-8298d0a7-94438c16-66607b23-27127377  19998330.0
#
#       EdemaSeverity  split
# 0                 0  train
# 1                 0  train
# 2                 0  train
# 3                 1  train
# 4                 0  train
# ...             ...    ...
# 7519              0  train
# 7521              0  train
# 7522              1  train
# 7523              1  train
# 7524              1  train
#
# [7223 rows x 5 columns]

# %%
dfm = pd.merge(df, edema_df, how='right', on=['study_id'])
# Out:
#                                                findings  study_id  \
# 0     \n \n Mild to moderate enlargement of the card...  54577367
# 1     \n \n The lungs are clear of consolidation, ef...  54980801
# 2     PA and lateral views of the chest demonstrate ...  59988438
# 4                                                   NaN  51895247
# 9      As compared to the previous radiograph, there...  50515796
# ...                                                 ...       ...
# 7215                                                NaN  57557006
# 7216  \n \n PA and lateral views of the chest provid...  57894530
# 7217   \n The patient is status post median sternoto...  58549312
# 7218   Comparison is made to previous radiographs fr...  58763598
# 7219   \n The patient is status post CABG with stern...  59159686
#
#                                           dicom_id  subject_id  EdemaSeverity  \
# 0     cfb03587-782edf6c-1bf392e1-98196cd5-365d69e8  10000980.0              0
# 1     a75a1fbe-802065ad-717eb7c1-e2ce3552-646276a6  10000980.0              0
# 2     925b9496-a956d7b2-05185e52-bb33313b-c06ee522  10000980.0              0
# 4     bf724128-9131f33a-6fd065d5-19041750-9e7f8707  10011938.0              0
# 9     906744d3-04cbdaa9-9b97b8ff-e89b52d6-be2d0f35  10018081.0              0
# ...                                            ...         ...            ...
# 7215  00cf50b3-4a8454a1-9117821e-e77b0df1-af78dcfd  19997367.0              0
# 7216  ed9f946b-d194e14a-8091f301-4bb11421-dcab0a36  19997367.0              0
# 7217  f72c9efb-07136e22-c4749961-b5e6c98a-a0804543  19997367.0              0
# 7218  7bdf562a-8945bd11-382bb25a-36306d5b-4c1f31f5  19997367.0              0
# 7219  a06c18fa-0be7ccf1-5b99ff5c-429949f2-86361e99  19997367.0              0
#
#       split
# 0     train
# 1     train
# 2     train
# 4     train
# 9     train
# ...     ...
# 7215  train
# 7216  train
# 7217  train
# 7218  train
# 7219  train
#
# [3317 rows x 6 columns]

# %%
import nltk

from nltk.collocations import *

def top_ngrams(text, n=2, freq_threshold=50, topn=100):
    tokens = nltk.wordpunct_tokenize(text)
    
    if n == 2:
        ngram_measures = nltk.collocations.BigramAssocMeasures()
        finder = BigramCollocationFinder.from_words(tokens)
    else:
        ngram_measures = nltk.collocations.TrigramAssocMeasures()
        finder = TrigramCollocationFinder.from_words(tokens)
        
    # occurs n_freq times
    finder.apply_freq_filter(freq_threshold)
    
    # with highest pmi
    ngrams  = finder.nbest(ngram_measures.pmi, topn)
    counts = [finder.ngram_fd[x] for x in ngrams]
    
    return list(zip(ngrams, counts))

data = {}
for i in range(4):
    print(f'Severity={i}')
    text = dfm[dfm['EdemaSeverity']==i]
    text = '\n'.join([x for x in text['findings'].to_list() if not isinstance(x, float)])
    ngrams = top_ngrams(text,n=2)
    data[i] = ngrams
    
    
data
# Out:
# Severity=0
# Severity=1
# Severity=2
# Severity=3
# {0: [(("'", 's'), 52),
#   (('costophrenic', 'angle'), 66),
#   (('PICC', 'line'), 50),
#   (('central', 'venous'), 52),
#   (('status', 'post'), 136),
#   (('In', 'comparison'), 131),
#   (('rib', 'fractures'), 67),
#   (('relevant', 'change'), 64),
#   (('Atherosclerotic', 'calcifications'), 52),
#   (('projecting', 'over'), 92),
#   (('pacing', 'device'), 57),
#   (('were', 'obtained'), 96),
#   (('aortic', 'arch'), 82),
#   (('aortic', 'knob'), 60),
#   (('post', 'median'), 85),
#   (('median', 'sternotomy'), 135),
#   (('Median', 'sternotomy'), 95),
#   (('concerning', 'for'), 80),
#   (('well', 'expanded'), 94),
#   (('degenerative', 'changes'), 113),
#   (('osseous', 'abnormalities'), 190),
#   (('cannot', 'be'), 60),
#   (('Lung', 'volumes'), 125),
#   (('has', 'been'), 177),
#   (('As', 'compared'), 195),
#   (('vascular', 'congestion'), 347),
#   (('sternotomy', 'wires'), 157),
#   (('acute', 'osseous'), 258),
#   (('leads', 'terminating'), 60),
#   (('upper', 'abdomen'), 67),
#   (('osseous', 'abnormality'), 70),
#   (('thoracic', 'spine'), 143),
#   (('lower', 'lobe'), 134),
#   (('been', 'interval'), 54),
#   (('may', 'be'), 104),
#   (('mediastinal', 'silhouettes'), 101),
#   (('previous', 'radiograph'), 179),
#   (('Heart', 'size'), 159),
#   (('moderately', 'enlarged'), 109),
#   (('lateral', 'views'), 304),
#   (('mildly', 'enlarged'), 214),
#   (('hilar', 'contours'), 409),
#   (('re', '-'), 60),
#   (('-', 'sided'), 293),
#   (('thoracic', 'aorta'), 122),
#   (('normal', 'limits'), 188),
#   (('Moderate', 'cardiomegaly'), 150),
#   (('severe', 'cardiomegaly'), 50),
#   (('chest', 'wall'), 115),
#   (('remains', 'mildly'), 56),
#   (('as', 'well'), 57),
#   (('well', 'as'), 55),
#   (('lung', 'bases'), 135),
#   (('prior', 'exam'), 97),
#   (('upper', 'lobe'), 73),
#   (('top', 'normal'), 73),
#   (('chest', 'were'), 108),
#   (('cardiac', 'silhouette'), 420),
#   (('Cardiac', 'silhouette'), 100),
#   (('bibasilar', 'atelectasis'), 76),
#   (('for', 'pneumonia'), 88),
#   (('Cardiomediastinal', 'silhouette'), 88),
#   (('due', 'to'), 163),
#   (('consistent', 'with'), 114),
#   (('compared', 'to'), 410),
#   (('lung', 'volumes'), 263),
#   (('focal', 'consolidation'), 697),
#   (('lateral', 'view'), 92),
#   (('prior', 'examination'), 50),
#   (('cardiomediastinal', 'silhouette'), 222),
#   (('chest', 'radiographs'), 86),
#   (('within', 'normal'), 188),
#   (('moderate', 'cardiomegaly'), 106),
#   (('prior', 'study'), 156),
#   (('compatible', 'with'), 82),
#   (('clear', 'without'), 211),
#   (('heart', 'size'), 143),
#   (('lung', 'base'), 144),
#   (('from', '___'), 147),
#   (('again', 'noted'), 207),
#   (('small', 'bilateral'), 54),
#   (('comparison', 'with'), 125),
#   (('overt', 'pulmonary'), 317),
#   (('frank', 'pulmonary'), 51),
#   (('pulmonary', 'edema'), 1266),
#   (('right', 'atrium'), 196),
#   (('terminating', 'in'), 107),
#   (('chest', 'demonstrate'), 60),
#   (('-', 'demonstrated'), 57),
#   (('no', 'relevant'), 67),
#   (('Mild', 'cardiomegaly'), 57),
#   (('right', 'ventricle'), 192),
#   (('pleural', 'effusions'), 421),
#   (('enlarged', 'but'), 88),
#   (('a', 'small'), 100),
#   (('pleural', 'effusion'), 1499),
#   (('low', 'lung'), 102),
#   (('Mediastinal', 'contours'), 52),
#   (('pulmonary', 'vasculature'), 89),
#   (('mid', 'lung'), 53)],
#  1: [(('costophrenic', 'angles'), 55),
#   (('were', 'obtained'), 75),
#   (('accompanied', 'by'), 78),
#   (('costophrenic', 'angle'), 60),
#   (('concerning', 'for'), 54),
#   (('In', 'comparison'), 97),
#   (('degenerative', 'changes'), 90),
#   (('status', 'post'), 156),
#   (('median', 'sternotomy'), 151),
#   (('post', 'median'), 119),
#   (('osseous', 'abnormalities'), 133),
#   (('thoracic', 'spine'), 100),
#   (('normal', 'limits'), 53),
#   (('Lung', 'volumes'), 84),
#   (('acute', 'osseous'), 185),
#   (('osseous', 'abnormality'), 52),
#   (('lateral', 'views'), 174),
#   (('has', 'been'), 126),
#   (('sternotomy', 'wires'), 83),
#   (('mediastinal', 'silhouettes'), 68),
#   (('Heart', 'size'), 119),
#   (('cannot', 'be'), 59),
#   (('lower', 'lobe'), 127),
#   (('without', 'overt'), 97),
#   (('as', 'well'), 82),
#   (('well', 'as'), 73),
#   (('chest', 'were'), 83),
#   (('sided', 'pacemaker'), 56),
#   (('hilar', 'contours'), 168),
#   (('moderately', 'enlarged'), 128),
#   (('within', 'normal'), 53),
#   (('may', 'be'), 152),
#   (('cardiac', 'silhouette'), 297),
#   (('focal', 'consolidation'), 394),
#   (('re', '-'), 75),
#   (('Cardiac', 'silhouette'), 96),
#   (('mildly', 'enlarged'), 148),
#   (('-', 'sided'), 234),
#   (('lung', 'bases'), 95),
#   (('definite', 'focal'), 51),
#   (('Small', 'bilateral'), 52),
#   (('Moderate', 'cardiomegaly'), 127),
#   (('prior', 'exam'), 92),
#   (('cardiomediastinal', 'silhouette'), 56),
#   (('be', 'due'), 67),
#   (('lung', 'volumes'), 157),
#   (('lung', 'base'), 111),
#   (('bibasilar', 'atelectasis'), 64),
#   (('prior', 'study'), 164),
#   (('Mediastinal', 'contours'), 52),
#   (('from', '___'), 81),
#   (('chest', 'radiograph'), 56),
#   (('difficult', 'to'), 56),
#   (('again', 'noted'), 143),
#   (('heart', 'size'), 63),
#   (('due', 'to'), 158),
#   (('consistent', 'with'), 136),
#   (('compatible', 'with'), 57),
#   (('small', 'bilateral'), 98),
#   (('right', 'atrium'), 114),
#   (('reflect', 'atelectasis'), 50),
#   (('compared', 'to'), 228),
#   (('mediastinal', 'contours'), 89),
#   (('low', 'lung'), 81),
#   (('terminating', 'in'), 73),
#   (('right', 'ventricle'), 121),
#   (('-', 'demonstrated'), 71),
#   (('vascular', 'congestion'), 1050),
#   (('Left', '-'), 68),
#   (('pleural', 'effusions'), 359),
#   (('No', 'definite'), 53),
#   (('pleural', 'effusion'), 904),
#   (('comparison', 'with'), 84),
#   (('No', 'acute'), 136),
#   (('or', 'pneumothorax'), 460),
#   (('Pulmonary', 'vascular'), 98),
#   (('silhouettes', 'are'), 73),
#   (('The', 'heart'), 166),
#   (('silhouette', 'remains'), 55),
#   (('The', 'lungs'), 97),
#   (('vascular', 'engorgement'), 149),
#   (('PA', 'and'), 71),
#   (('contours', 'are'), 306),
#   (('a', 'small'), 95),
#   (('Frontal', 'and'), 116),
#   (('bilateral', 'pleural'), 226),
#   (('The', 'aorta'), 103),
#   (('right', 'hemidiaphragm'), 55),
#   (('The', 'patient'), 116),
#   (('pulmonary', 'vascular'), 1105),
#   (('effusion', 'or'), 382),
#   (('views', 'of'), 175),
#   (('again', 'seen'), 114),
#   (('with', 'leads'), 73),
#   (('evidence', 'of'), 162),
#   (('No', 'large'), 82),
#   (('blunting', 'of'), 56),
#   (('The', 'cardiomediastinal'), 50),
#   (('large', 'pleural'), 102),
#   (('pulmonary', 'edema'), 397)],
#  2: [(("'", 's'), 55),
#   (('significantly', 'changed'), 53),
#   (('greater', 'than'), 50),
#   (('status', 'post'), 150),
#   (('degenerative', 'changes'), 68),
#   (('Lung', 'volumes'), 63),
#   (('aortic', 'knob'), 57),
#   (('concerning', 'for'), 51),
#   (('osseous', 'abnormalities'), 86),
#   (('Bony', 'structures'), 118),
#   (('not', 'significantly'), 54),
#   (('were', 'obtained'), 96),
#   (('acute', 'osseous'), 124),
#   (('post', 'median'), 80),
#   (('median', 'sternotomy'), 115),
#   (('AP', 'upright'), 61),
#   (('thoracic', 'spine'), 98),
#   (('has', 'been'), 144),
#   (('sternotomy', 'wires'), 116),
#   (('mediastinal', 'silhouettes'), 73),
#   (('Heart', 'size'), 114),
#   (('lower', 'lobe'), 105),
#   (('as', 'well'), 105),
#   (('vascular', 'congestion'), 249),
#   (('lateral', 'views'), 284),
#   (('normal', 'limits'), 68),
#   (('top', 'normal'), 56),
#   (('hilar', 'contours'), 227),
#   (('may', 'represent'), 53),
#   (('been', 'interval'), 52),
#   (('moderately', 'enlarged'), 141),
#   (('thoracic', 'aorta'), 81),
#   (('well', 'as'), 87),
#   (('Moderate', 'cardiomegaly'), 95),
#   (('Cardiomediastinal', 'silhouette'), 59),
#   (('cardiomediastinal', 'silhouette'), 98),
#   (('may', 'be'), 131),
#   (('Cardiac', 'silhouette'), 65),
#   (('could', 'be'), 52),
#   (('for', 'pneumonia'), 64),
#   (('re', '-'), 57),
#   (('mildly', 'enlarged'), 166),
#   (('Small', 'bilateral'), 78),
#   (('focal', 'consolidation'), 296),
#   (('-', 'sided'), 179),
#   (('cardiac', 'silhouette'), 209),
#   (('upper', 'lobe'), 50),
#   (('contours', 'appear'), 97),
#   (('chest', 'were'), 126),
#   (('be', 'due'), 65),
#   (('lung', 'bases'), 102),
#   (('within', 'normal'), 68),
#   (('lung', 'volumes'), 129),
#   (('prior', 'exam'), 108),
#   (('lung', 'disease'), 75),
#   (('prior', 'study'), 149),
#   (('lung', 'base'), 105),
#   (('lateral', 'view'), 53),
#   (('from', '___'), 111),
#   (('which', 'may'), 59),
#   (('markings', 'bilaterally'), 56),
#   (('prior', 'examination'), 54),
#   (('due', 'to'), 179),
#   (('again', 'noted'), 153),
#   (('difficult', 'to'), 60),
#   (('chest', 'provided'), 65),
#   (('compatible', 'with'), 107),
#   (('right', 'atrium'), 123),
#   (('compared', 'to'), 254),
#   (('consistent', 'with'), 174),
#   (('pulmonary', 'vasculature'), 75),
#   (('right', 'ventricle'), 107),
#   (('small', 'bilateral'), 125),
#   (('terminating', 'in'), 65),
#   (('increase', 'in'), 86),
#   (('low', 'lung'), 65),
#   (('pleural', 'effusions'), 476),
#   (('No', 'acute'), 110),
#   (('mediastinal', 'contours'), 102),
#   (('heart', 'size'), 84),
#   (('pleural', 'effusion'), 839),
#   (('Mild', 'cardiomegaly'), 66),
#   (('or', 'pneumothorax'), 471),
#   (('interstitial', 'markings'), 455),
#   (('no', 'definite'), 50),
#   (('right', 'hemidiaphragm'), 64),
#   (('chest', 'radiograph'), 56),
#   (('The', 'heart'), 330),
#   (('No', 'large'), 106),
#   (('pulmonary', 'vascular'), 213),
#   (('The', 'cardiomediastinal'), 115),
#   (('appear', 'unchanged'), 71),
#   (('interstitial', 'abnormality'), 174),
#   (('effusion', 'or'), 384),
#   (('suggestive', 'of'), 90),
#   (('silhouettes', 'are'), 76),
#   (('bilateral', 'pleural'), 279),
#   (('PA', 'and'), 164),
#   (('Increased', 'interstitial'), 81),
#   (('again', 'seen'), 136)],
#  3: [(('pleural', 'effusions'), 55),
#   (('pleural', 'effusion'), 51),
#   (('pulmonary', 'edema'), 97),
#   (('severe', 'pulmonary'), 74),
#   (('There', 'is'), 87),
#   (('of', 'the'), 79),
#   (('.', 'No'), 62),
#   (('.', 'There'), 122),
#   (('.', 'The'), 105),
#   (('pneumothorax', '.'), 55)]}

# %%
data
# Out:
# {0: [(("'", 's'), 52),
#   (('costophrenic', 'angle'), 66),
#   (('PICC', 'line'), 50),
#   (('central', 'venous'), 52),
#   (('status', 'post'), 136),
#   (('In', 'comparison'), 131),
#   (('rib', 'fractures'), 67),
#   (('relevant', 'change'), 64),
#   (('Atherosclerotic', 'calcifications'), 52),
#   (('projecting', 'over'), 92),
#   (('pacing', 'device'), 57),
#   (('were', 'obtained'), 96),
#   (('aortic', 'arch'), 82),
#   (('aortic', 'knob'), 60),
#   (('post', 'median'), 85),
#   (('median', 'sternotomy'), 135),
#   (('Median', 'sternotomy'), 95),
#   (('concerning', 'for'), 80),
#   (('well', 'expanded'), 94),
#   (('degenerative', 'changes'), 113),
#   (('osseous', 'abnormalities'), 190),
#   (('cannot', 'be'), 60),
#   (('Lung', 'volumes'), 125),
#   (('has', 'been'), 177),
#   (('As', 'compared'), 195),
#   (('vascular', 'congestion'), 347),
#   (('sternotomy', 'wires'), 157),
#   (('acute', 'osseous'), 258),
#   (('leads', 'terminating'), 60),
#   (('upper', 'abdomen'), 67),
#   (('osseous', 'abnormality'), 70),
#   (('thoracic', 'spine'), 143),
#   (('lower', 'lobe'), 134),
#   (('been', 'interval'), 54),
#   (('may', 'be'), 104),
#   (('mediastinal', 'silhouettes'), 101),
#   (('previous', 'radiograph'), 179),
#   (('Heart', 'size'), 159),
#   (('moderately', 'enlarged'), 109),
#   (('lateral', 'views'), 304),
#   (('mildly', 'enlarged'), 214),
#   (('hilar', 'contours'), 409),
#   (('re', '-'), 60),
#   (('-', 'sided'), 293),
#   (('thoracic', 'aorta'), 122),
#   (('normal', 'limits'), 188),
#   (('Moderate', 'cardiomegaly'), 150),
#   (('severe', 'cardiomegaly'), 50),
#   (('chest', 'wall'), 115),
#   (('remains', 'mildly'), 56),
#   (('as', 'well'), 57),
#   (('well', 'as'), 55),
#   (('lung', 'bases'), 135),
#   (('prior', 'exam'), 97),
#   (('upper', 'lobe'), 73),
#   (('top', 'normal'), 73),
#   (('chest', 'were'), 108),
#   (('cardiac', 'silhouette'), 420),
#   (('Cardiac', 'silhouette'), 100),
#   (('bibasilar', 'atelectasis'), 76),
#   (('for', 'pneumonia'), 88),
#   (('Cardiomediastinal', 'silhouette'), 88),
#   (('due', 'to'), 163),
#   (('consistent', 'with'), 114),
#   (('compared', 'to'), 410),
#   (('lung', 'volumes'), 263),
#   (('focal', 'consolidation'), 697),
#   (('lateral', 'view'), 92),
#   (('prior', 'examination'), 50),
#   (('cardiomediastinal', 'silhouette'), 222),
#   (('chest', 'radiographs'), 86),
#   (('within', 'normal'), 188),
#   (('moderate', 'cardiomegaly'), 106),
#   (('prior', 'study'), 156),
#   (('compatible', 'with'), 82),
#   (('clear', 'without'), 211),
#   (('heart', 'size'), 143),
#   (('lung', 'base'), 144),
#   (('from', '___'), 147),
#   (('again', 'noted'), 207),
#   (('small', 'bilateral'), 54),
#   (('comparison', 'with'), 125),
#   (('overt', 'pulmonary'), 317),
#   (('frank', 'pulmonary'), 51),
#   (('pulmonary', 'edema'), 1266),
#   (('right', 'atrium'), 196),
#   (('terminating', 'in'), 107),
#   (('chest', 'demonstrate'), 60),
#   (('-', 'demonstrated'), 57),
#   (('no', 'relevant'), 67),
#   (('Mild', 'cardiomegaly'), 57),
#   (('right', 'ventricle'), 192),
#   (('pleural', 'effusions'), 421),
#   (('enlarged', 'but'), 88),
#   (('a', 'small'), 100),
#   (('pleural', 'effusion'), 1499),
#   (('low', 'lung'), 102),
#   (('Mediastinal', 'contours'), 52),
#   (('pulmonary', 'vasculature'), 89),
#   (('mid', 'lung'), 53)],
#  1: [(('costophrenic', 'angles'), 55),
#   (('were', 'obtained'), 75),
#   (('accompanied', 'by'), 78),
#   (('costophrenic', 'angle'), 60),
#   (('concerning', 'for'), 54),
#   (('In', 'comparison'), 97),
#   (('degenerative', 'changes'), 90),
#   (('status', 'post'), 156),
#   (('median', 'sternotomy'), 151),
#   (('post', 'median'), 119),
#   (('osseous', 'abnormalities'), 133),
#   (('thoracic', 'spine'), 100),
#   (('normal', 'limits'), 53),
#   (('Lung', 'volumes'), 84),
#   (('acute', 'osseous'), 185),
#   (('osseous', 'abnormality'), 52),
#   (('lateral', 'views'), 174),
#   (('has', 'been'), 126),
#   (('sternotomy', 'wires'), 83),
#   (('mediastinal', 'silhouettes'), 68),
#   (('Heart', 'size'), 119),
#   (('cannot', 'be'), 59),
#   (('lower', 'lobe'), 127),
#   (('without', 'overt'), 97),
#   (('as', 'well'), 82),
#   (('well', 'as'), 73),
#   (('chest', 'were'), 83),
#   (('sided', 'pacemaker'), 56),
#   (('hilar', 'contours'), 168),
#   (('moderately', 'enlarged'), 128),
#   (('within', 'normal'), 53),
#   (('may', 'be'), 152),
#   (('cardiac', 'silhouette'), 297),
#   (('focal', 'consolidation'), 394),
#   (('re', '-'), 75),
#   (('Cardiac', 'silhouette'), 96),
#   (('mildly', 'enlarged'), 148),
#   (('-', 'sided'), 234),
#   (('lung', 'bases'), 95),
#   (('definite', 'focal'), 51),
#   (('Small', 'bilateral'), 52),
#   (('Moderate', 'cardiomegaly'), 127),
#   (('prior', 'exam'), 92),
#   (('cardiomediastinal', 'silhouette'), 56),
#   (('be', 'due'), 67),
#   (('lung', 'volumes'), 157),
#   (('lung', 'base'), 111),
#   (('bibasilar', 'atelectasis'), 64),
#   (('prior', 'study'), 164),
#   (('Mediastinal', 'contours'), 52),
#   (('from', '___'), 81),
#   (('chest', 'radiograph'), 56),
#   (('difficult', 'to'), 56),
#   (('again', 'noted'), 143),
#   (('heart', 'size'), 63),
#   (('due', 'to'), 158),
#   (('consistent', 'with'), 136),
#   (('compatible', 'with'), 57),
#   (('small', 'bilateral'), 98),
#   (('right', 'atrium'), 114),
#   (('reflect', 'atelectasis'), 50),
#   (('compared', 'to'), 228),
#   (('mediastinal', 'contours'), 89),
#   (('low', 'lung'), 81),
#   (('terminating', 'in'), 73),
#   (('right', 'ventricle'), 121),
#   (('-', 'demonstrated'), 71),
#   (('vascular', 'congestion'), 1050),
#   (('Left', '-'), 68),
#   (('pleural', 'effusions'), 359),
#   (('No', 'definite'), 53),
#   (('pleural', 'effusion'), 904),
#   (('comparison', 'with'), 84),
#   (('No', 'acute'), 136),
#   (('or', 'pneumothorax'), 460),
#   (('Pulmonary', 'vascular'), 98),
#   (('silhouettes', 'are'), 73),
#   (('The', 'heart'), 166),
#   (('silhouette', 'remains'), 55),
#   (('The', 'lungs'), 97),
#   (('vascular', 'engorgement'), 149),
#   (('PA', 'and'), 71),
#   (('contours', 'are'), 306),
#   (('a', 'small'), 95),
#   (('Frontal', 'and'), 116),
#   (('bilateral', 'pleural'), 226),
#   (('The', 'aorta'), 103),
#   (('right', 'hemidiaphragm'), 55),
#   (('The', 'patient'), 116),
#   (('pulmonary', 'vascular'), 1105),
#   (('effusion', 'or'), 382),
#   (('views', 'of'), 175),
#   (('again', 'seen'), 114),
#   (('with', 'leads'), 73),
#   (('evidence', 'of'), 162),
#   (('No', 'large'), 82),
#   (('blunting', 'of'), 56),
#   (('The', 'cardiomediastinal'), 50),
#   (('large', 'pleural'), 102),
#   (('pulmonary', 'edema'), 397)],
#  2: [(("'", 's'), 55),
#   (('significantly', 'changed'), 53),
#   (('greater', 'than'), 50),
#   (('status', 'post'), 150),
#   (('degenerative', 'changes'), 68),
#   (('Lung', 'volumes'), 63),
#   (('aortic', 'knob'), 57),
#   (('concerning', 'for'), 51),
#   (('osseous', 'abnormalities'), 86),
#   (('Bony', 'structures'), 118),
#   (('not', 'significantly'), 54),
#   (('were', 'obtained'), 96),
#   (('acute', 'osseous'), 124),
#   (('post', 'median'), 80),
#   (('median', 'sternotomy'), 115),
#   (('AP', 'upright'), 61),
#   (('thoracic', 'spine'), 98),
#   (('has', 'been'), 144),
#   (('sternotomy', 'wires'), 116),
#   (('mediastinal', 'silhouettes'), 73),
#   (('Heart', 'size'), 114),
#   (('lower', 'lobe'), 105),
#   (('as', 'well'), 105),
#   (('vascular', 'congestion'), 249),
#   (('lateral', 'views'), 284),
#   (('normal', 'limits'), 68),
#   (('top', 'normal'), 56),
#   (('hilar', 'contours'), 227),
#   (('may', 'represent'), 53),
#   (('been', 'interval'), 52),
#   (('moderately', 'enlarged'), 141),
#   (('thoracic', 'aorta'), 81),
#   (('well', 'as'), 87),
#   (('Moderate', 'cardiomegaly'), 95),
#   (('Cardiomediastinal', 'silhouette'), 59),
#   (('cardiomediastinal', 'silhouette'), 98),
#   (('may', 'be'), 131),
#   (('Cardiac', 'silhouette'), 65),
#   (('could', 'be'), 52),
#   (('for', 'pneumonia'), 64),
#   (('re', '-'), 57),
#   (('mildly', 'enlarged'), 166),
#   (('Small', 'bilateral'), 78),
#   (('focal', 'consolidation'), 296),
#   (('-', 'sided'), 179),
#   (('cardiac', 'silhouette'), 209),
#   (('upper', 'lobe'), 50),
#   (('contours', 'appear'), 97),
#   (('chest', 'were'), 126),
#   (('be', 'due'), 65),
#   (('lung', 'bases'), 102),
#   (('within', 'normal'), 68),
#   (('lung', 'volumes'), 129),
#   (('prior', 'exam'), 108),
#   (('lung', 'disease'), 75),
#   (('prior', 'study'), 149),
#   (('lung', 'base'), 105),
#   (('lateral', 'view'), 53),
#   (('from', '___'), 111),
#   (('which', 'may'), 59),
#   (('markings', 'bilaterally'), 56),
#   (('prior', 'examination'), 54),
#   (('due', 'to'), 179),
#   (('again', 'noted'), 153),
#   (('difficult', 'to'), 60),
#   (('chest', 'provided'), 65),
#   (('compatible', 'with'), 107),
#   (('right', 'atrium'), 123),
#   (('compared', 'to'), 254),
#   (('consistent', 'with'), 174),
#   (('pulmonary', 'vasculature'), 75),
#   (('right', 'ventricle'), 107),
#   (('small', 'bilateral'), 125),
#   (('terminating', 'in'), 65),
#   (('increase', 'in'), 86),
#   (('low', 'lung'), 65),
#   (('pleural', 'effusions'), 476),
#   (('No', 'acute'), 110),
#   (('mediastinal', 'contours'), 102),
#   (('heart', 'size'), 84),
#   (('pleural', 'effusion'), 839),
#   (('Mild', 'cardiomegaly'), 66),
#   (('or', 'pneumothorax'), 471),
#   (('interstitial', 'markings'), 455),
#   (('no', 'definite'), 50),
#   (('right', 'hemidiaphragm'), 64),
#   (('chest', 'radiograph'), 56),
#   (('The', 'heart'), 330),
#   (('No', 'large'), 106),
#   (('pulmonary', 'vascular'), 213),
#   (('The', 'cardiomediastinal'), 115),
#   (('appear', 'unchanged'), 71),
#   (('interstitial', 'abnormality'), 174),
#   (('effusion', 'or'), 384),
#   (('suggestive', 'of'), 90),
#   (('silhouettes', 'are'), 76),
#   (('bilateral', 'pleural'), 279),
#   (('PA', 'and'), 164),
#   (('Increased', 'interstitial'), 81),
#   (('again', 'seen'), 136)],
#  3: [(('pleural', 'effusions'), 55),
#   (('pleural', 'effusion'), 51),
#   (('pulmonary', 'edema'), 97),
#   (('severe', 'pulmonary'), 74),
#   (('There', 'is'), 87),
#   (('of', 'the'), 79),
#   (('.', 'No'), 62),
#   (('.', 'There'), 122),
#   (('.', 'The'), 105),
#   (('pneumothorax', '.'), 55)]}

# %%
from nltk.tokenize import RegexpTokenizer


text = '\n'.join([x for x in dfm['findings'].to_list() if not isinstance(x, float)])
print(len(text))

## tokenization
# tokens = nltk.wordpunct_tokenize(text)
# print(len(tokens))
tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(text)


bigram_measures = nltk.collocations.BigramAssocMeasures()

# bigram pmi
finder = BigramCollocationFinder.from_words(tokens)

# finder
# # # only bigrams that appear 3+ times
finder.apply_freq_filter(100)

# return the 10 n-grams with the highest PMI
bigrams = finder.nbest(bigram_measures.pmi, 1000)
fd_counts = [finder.ngram_fd[x] for x in bigrams]
list(zip(bigrams, fd_counts))
# Out:
# 2222280
# [(('clinical', 'setting'), 101),
#  (('significantly', 'changed'), 109),
#  (('valve', 'replacement'), 101),
#  (('costophrenic', 'angles'), 131),
#  (('accompanied', 'by'), 133),
#  (('greater', 'than'), 145),
#  (('rib', 'fractures'), 138),
#  (('costophrenic', 'angle'), 163),
#  (('re', 'demonstrated'), 168),
#  (('In', 'comparison'), 265),
#  (('projecting', 'over'), 187),
#  (('status', 'post'), 448),
#  (('Bony', 'structures'), 203),
#  (('were', 'obtained'), 270),
#  (('aortic', 'knob'), 168),
#  (('concerning', 'for'), 189),
#  (('aortic', 'arch'), 162),
#  (('central', 'venous'), 139),
#  (('well', 'expanded'), 164),
#  (('degenerative', 'changes'), 272),
#  (('venous', 'catheter'), 111),
#  (('post', 'median'), 290),
#  (('not', 'significantly'), 110),
#  (('median', 'sternotomy'), 405),
#  (('Median', 'sternotomy'), 176),
#  (('osseous', 'abnormalities'), 412),
#  (('AP', 'upright'), 137),
#  (('single', 'lead'), 107),
#  (('Lung', 'volumes'), 279),
#  (('dual', 'lead'), 119),
#  (('acute', 'osseous'), 573),
#  (('patient', 's'), 109),
#  (('cannot', 'be'), 181),
#  (('thoracic', 'spine'), 341),
#  (('As', 'compared'), 265),
#  (('leads', 'terminating'), 131),
#  (('has', 'been'), 457),
#  (('sternotomy', 'wires'), 366),
#  (('upper', 'abdomen'), 135),
#  (('top', 'normal'), 251),
#  (('Mediastinal', 'contour'), 118),
#  (('mediastinal', 'silhouettes'), 242),
#  (('lower', 'lobe'), 380),
#  (('Heart', 'size'), 400),
#  (('lateral', 'views'), 773),
#  (('not', 'excluded'), 101),
#  (('previous', 'radiograph'), 221),
#  (('been', 'interval'), 153),
#  (('normal', 'limits'), 310),
#  (('osseous', 'abnormality'), 164),
#  (('as', 'well'), 249),
#  (('hilar', 'contours'), 809),
#  (('may', 'reflect'), 117),
#  (('moderately', 'enlarged'), 388),
#  (('may', 'be'), 395),
#  (('Left', 'sided'), 166),
#  (('well', 'as'), 219),
#  (('thoracic', 'aorta'), 246),
#  (('retrocardiac', 'opacity'), 126),
#  (('chest', 'wall'), 213),
#  (('mildly', 'enlarged'), 538),
#  (('Small', 'bilateral'), 180),
#  (('interstitial', 'markings'), 460),
#  (('clear', 'without'), 271),
#  (('be', 'excluded'), 123),
#  (('vascular', 'congestion'), 1651),
#  (('Moderate', 'cardiomegaly'), 382),
#  (('chest', 'were'), 320),
#  (('Cardiac', 'silhouette'), 266),
#  (('without', 'overt'), 157),
#  (('cardiac', 'silhouette'), 943),
#  (('for', 'pneumonia'), 197),
#  (('Cardiomediastinal', 'silhouette'), 188),
#  (('could', 'be'), 117),
#  (('lung', 'bases'), 341),
#  (('focal', 'consolidation'), 1390),
#  (('sided', 'pacemaker'), 128),
#  (('cardiomediastinal', 'silhouette'), 379),
#  (('prior', 'exam'), 303),
#  (('be', 'due'), 183),
#  (('within', 'normal'), 311),
#  (('vascular', 'engorgement'), 198),
#  (('upper', 'lobe'), 165),
#  (('bibasilar', 'atelectasis'), 172),
#  (('severe', 'cardiomegaly'), 129),
#  (('lung', 'volumes'), 555),
#  (('remains', 'mildly'), 111),
#  (('osseous', 'structures'), 114),
#  (('lateral', 'view'), 188),
#  (('prior', 'examination'), 142),
#  (('prior', 'study'), 479),
#  (('lung', 'base'), 361),
#  (('which', 'may'), 142),
#  (('chest', 'provided'), 132),
#  (('due', 'to'), 509),
#  (('from', '___'), 346),
#  (('difficult', 'to'), 166),
#  (('chest', 'radiographs'), 153),
#  (('consistent', 'with'), 438),
#  (('to', 'exclude'), 114),
#  (('compared', 'to'), 917),
#  (('again', 'noted'), 509),
#  (('Pulmonary', 'vascular'), 124),
#  (('compatible', 'with'), 255),
#  (('interstitial', 'abnormality'), 176),
#  (('chest', 'demonstrate'), 121),
#  (('since', '___'), 138),
#  (('in', 'place'), 103),
#  (('small', 'bilateral'), 289),
#  (('heart', 'size'), 297),
#  (('contours', 'appear'), 133),
#  (('right', 'atrium'), 444),
#  (('mediastinal', 'clips'), 102),
#  (('increase', 'in'), 155),
#  (('reflect', 'atelectasis'), 104),
#  (('terminating', 'in'), 247),
#  (('definite', 'focal'), 112),
#  (('right', 'ventricle'), 425),
#  (('Again', 'seen'), 132),
#  (('Mediastinal', 'contours'), 135),
#  (('low', 'lung'), 250),
#  (('pleural', 'effusions'), 1311),
#  (('comparison', 'with'), 242),
#  (('overt', 'pulmonary'), 452),
#  (('mediastinal', 'contours'), 319),
#  (('pleural', 'effusion'), 3293),
#  (('radiograph', 'there'), 130),
#  (('Compared', 'to'), 102),
#  (('size', 'remains'), 104),
#  (('No', 'acute'), 494),
#  (('mid', 'lung'), 136),
#  (('pulmonary', 'edema'), 2363),
#  (('Mild', 'cardiomegaly'), 178),
#  (('moderate', 'cardiomegaly'), 229),
#  (('enlarged', 'but'), 205),
#  (('chest', 'radiograph'), 209),
#  (('silhouette', 'remains'), 146),
#  (('pulmonary', 'vasculature'), 246),
#  (('pulmonary', 'vascular'), 1500),
#  (('or', 'pneumothorax'), 1787),
#  (('to', 'severe'), 165),
#  (('without', 'focal'), 196),
#  (('PA', 'and'), 453),
#  (('there', 'has'), 153),
#  (('silhouettes', 'are'), 264),
#  (('The', 'heart'), 809),
#  (('The', 'cardiomediastinal'), 454),
#  (('Frontal', 'and'), 445),
#  (('a', 'small'), 312),
#  (('suggestive', 'of'), 177),
#  (('right', 'hemidiaphragm'), 204),
#  (('No', 'definite'), 155),
#  (('again', 'seen'), 437),
#  (('effusion', 'or'), 1717),
#  (('enlarged', 'Mediastinal'), 108),
#  (('___', 'there'), 215),
#  (('blunting', 'of'), 175),
#  (('bilateral', 'pleural'), 687),
#  (('The', 'lungs'), 720),
#  (('views', 'of'), 764),
#  (('terminates', 'in'), 123),
#  (('elevation', 'of'), 102),
#  (('left', 'sided'), 279),
#  (('left', 'hemidiaphragm'), 134),
#  (('evidence', 'of'), 749),
#  (('contours', 'are'), 1183),
#  (('Lungs', 'are'), 156),
#  (('increased', 'interstitial'), 171),
#  (('no', 'evidence'), 341),
#  (('pleural', 'thickening'), 123),
#  (('with', 'leads'), 232),
#  (('areas', 'of'), 126),
#  (('tortuosity', 'of'), 115),
#  (('from', 'prior'), 180),
#  (('and', 'hilar'), 801),
#  (('and', 'lateral'), 1075),
#  (('large', 'pleural'), 299),
#  (('lower', 'lung'), 200),
#  (('enlargement', 'of'), 356),
#  (('No', 'large'), 239),
#  (('similar', 'to'), 240),
#  (('mild', 'interstitial'), 374),
#  (('lungs', 'are'), 769),
#  (('The', 'patient'), 397),
#  (('prominence', 'of'), 235),
#  (('interstitial', 'edema'), 554),
#  (('central', 'pulmonary'), 197),
#  (('The', 'cardiac'), 698),
#  (('no', 'overt'), 175),
#  (('are', 'otherwise'), 126),
#  (('unchanged', 'from'), 194),
#  (('are', 'intact'), 311),
#  (('atrium', 'and'), 278),
#  (('but', 'stable'), 111),
#  (('structures', 'are'), 335),
#  (('unchanged', 'position'), 133),
#  (('to', 'moderate'), 334),
#  (('are', 'hyperinflated'), 100),
#  (('are', 'unremarkable'), 319),
#  (('and', 'CABG'), 163),
#  (('No', 'focal'), 559),
#  (('The', 'aorta'), 309),
#  (('lateral', 'chest'), 223),
#  (('are', 'clear'), 453),
#  (('left', 'lower'), 214),
#  (('below', 'the'), 107),
#  (('right', 'sided'), 244),
#  (('the', 'carina'), 102),
#  (('fractures', 'are'), 103),
#  (('no', 'focal'), 472),
#  (('right', 'upper'), 258),
#  (('over', 'the'), 360),
#  (('volumes', 'are'), 407),
#  (('The', 'mediastinal'), 465),
#  (('in', 'position'), 182),
#  (('mild', 'pulmonary'), 619),
#  (('atelectasis', 'at'), 124),
#  (('are', 'low'), 278),
#  (('calcifications', 'are'), 173),
#  (('clips', 'are'), 170),
#  (('along', 'the'), 188),
#  (('at', 'the'), 908),
#  (('right', 'lower'), 232),
#  (('Mediastinal', 'and'), 216),
#  (('seen', 'on'), 211),
#  (('No', 'overt'), 124),
#  (('appearance', 'of'), 109),
#  (('is', 'status'), 430),
#  (('wires', 'are'), 235),
#  (('A', 'left'), 165),
#  (('and', 'mediastinal'), 507),
#  (('on', 'prior'), 132),
#  (('no', 'large'), 118),
#  (('no', 'pneumothorax'), 730),
#  (('No', 'evidence'), 177),
#  (('the', 'previous'), 363),
#  (('small', 'left'), 188),
#  (('left', 'base'), 103),
#  (('is', 'made'), 121),
#  (('no', 'acute'), 150),
#  (('No', 'pneumothorax'), 761),
#  (('Patient', 'is'), 139),
#  (('large', 'effusion'), 121),
#  (('region', 'of'), 101),
#  (('changes', 'are'), 242),
#  (('to', 'prior'), 374),
#  (('mild', 'cardiomegaly'), 149),
#  (('consolidation', 'or'), 364),
#  (('in', 'size'), 266),
#  (('is', 'top'), 206),
#  (('There', 'is'), 5085),
#  (('obtained', 'The'), 100),
#  (('on', 'the'), 787),
#  (('are', 'stable'), 554),
#  (('left', 'upper'), 127),
#  (('No', 'new'), 102),
#  (('is', 'no'), 2769),
#  (('but', 'no'), 134),
#  (('Mild', 'pulmonary'), 177),
#  (('there', 'is'), 814),
#  (('sternotomy', 'and'), 240),
#  (('small', 'right'), 211),
#  (('the', 'thoracic'), 412),
#  (('wires', 'and'), 178),
#  (('in', 'the'), 2426),
#  (('the', 'chest'), 1095),
#  (('of', 'the'), 4205),
#  (('view', 'of'), 143),
#  (('consolidation', 'pleural'), 432),
#  (('to', 'be'), 165),
#  (('are', 'well'), 166),
#  (('right', 'base'), 110),
#  (('left', 'lung'), 280),
#  (('are', 'again'), 338),
#  (('within', 'the'), 361),
#  (('the', 'right'), 2255),
#  (('opacity', 'in'), 168),
#  (('mediastinal', 'and'), 351),
#  (('the', 'aortic'), 245),
#  (('is', 'detected'), 134),
#  (('study', 'of'), 253),
#  (('interstitial', 'pulmonary'), 300),
#  (('silhouette', 'is'), 1089),
#  (('opacities', 'in'), 138),
#  (('contour', 'is'), 187),
#  (('is', 're'), 113),
#  (('AP', 'and'), 107),
#  (('are', 'noted'), 439),
#  (('with', 'mild'), 288),
#  (('enlarged', 'The'), 311),
#  (('A', 'right'), 138),
#  (('unremarkable', 'There'), 118),
#  (('is', 'present'), 460),
#  (('the', 'prior'), 825),
#  (('sided', 'pleural'), 120),
#  (('device', 'is'), 214),
#  (('is', 'identified'), 347),
#  (('is', 'mildly'), 388),
#  (('effusions', 'are'), 339),
#  (('are', 'normal'), 306),
#  (('right', 'lung'), 308),
#  (('moderate', 'pulmonary'), 160),
#  (('are', 'present'), 188),
#  (('is', 'not'), 309),
#  (('no', 'pleural'), 551),
#  (('the', 'left'), 1277),
#  (('is', 'persistent'), 118),
#  (('patient', 'is'), 372),
#  (('is', 'again'), 590),
#  (('cardiomediastinal', 'and'), 129),
#  (('is', 'moderately'), 209),
#  (('identified', 'There'), 115),
#  (('edema', 'No'), 371),
#  (('aorta', 'is'), 347),
#  (('is', 'also'), 237),
#  (('the', 'mid'), 148),
#  (('effusions', 'No'), 162),
#  (('moderate', 'to'), 117),
#  (('mild', 'to'), 227),
#  (('No', 'pleural'), 545),
#  (('since', 'the'), 143),
#  (('atelectasis', 'No'), 186),
#  (('left', 'pleural'), 428),
#  (('clear', 'There'), 142),
#  (('are', 'within'), 137),
#  (('are', 'unchanged'), 499),
#  (('is', 'seen'), 1284),
#  (('size', 'is'), 538),
#  (('pneumothorax', 'or'), 330),
#  (('vasculature', 'is'), 152),
#  (('noted', 'in'), 196),
#  (('pneumothorax', 'The'), 516),
#  (('markings', 'are'), 110),
#  (('heart', 'is'), 455),
#  (('the', 'cardiac'), 459),
#  (('There', 'has'), 159),
#  (('of', '___'), 297),
#  (('noted', 'with'), 176),
#  (('small', 'pleural'), 135),
#  (('present', 'There'), 125),
#  (('is', 'calcified'), 143),
#  (('opacities', 'are'), 152),
#  (('is', 'unchanged'), 1016),
#  (('with', 'a'), 198),
#  (('cardiomegaly', 'is'), 549),
#  (('and', 'there'), 183),
#  (('stable', 'There'), 236),
#  (('right', 'pleural'), 486),
#  (('There', 'may'), 101),
#  (('a', 'left'), 147),
#  (('to', '___'), 130),
#  (('normal', 'The'), 158),
#  (('stable', 'No'), 140),
#  (('abnormality', 'is'), 147),
#  (('from', 'the'), 242),
#  (('___', 'There'), 202),
#  (('is', 'mild'), 729),
#  (('to', 'the'), 1040),
#  (('effusions', 'or'), 100),
#  (('of', 'pneumonia'), 135),
#  (('unchanged', 'There'), 325),
#  (('normal', 'in'), 116),
#  (('is', 'stable'), 554),
#  (('left', 'chest'), 125),
#  (('There', 'are'), 891),
#  (('unchanged', 'The'), 276),
#  (('is', 'tortuous'), 130),
#  (('cardiac', 'and'), 191),
#  (('seen', 'There'), 341),
#  (('congestion', 'or'), 115),
#  (('are', 'small'), 151),
#  (('the', 'upper'), 208),
#  (('seen', 'in'), 230),
#  (('congestion', 'and'), 238),
#  (('pneumonia', 'There'), 100),
#  (('is', 'a'), 642),
#  (('seen', 'The'), 285),
#  (('edema', 'There'), 373),
#  (('unchanged', 'in'), 202),
#  (('hemidiaphragm', 'is'), 107),
#  (('enlarged', 'There'), 178),
#  (('are', 'seen'), 346),
#  (('of', 'a'), 273),
#  (('edema', 'or'), 185),
#  (('consolidation', 'effusion'), 138),
#  (('is', 'noted'), 481),
#  (('cardiomegaly', 'and'), 162),
#  (('is', 'unremarkable'), 152),
#  (('which', 'is'), 198),
#  (('is', 'slightly'), 135),
#  (('normal', 'There'), 133),
#  (('congestion', 'No'), 112),
#  (('pneumothorax', 'is'), 970),
#  (('the', 'patient'), 153),
#  (('seen', 'No'), 175),
#  (('no', 'pulmonary'), 259),
#  (('___', 'The'), 131),
#  (('pacemaker', 'is'), 126),
#  (('or', 'pleural'), 250),
#  (('pneumothorax', 'No'), 217),
#  (('is', 'similar'), 153),
#  (('noted', 'There'), 162),
#  (('in', 'unchanged'), 162),
#  (('edema', 'The'), 258),
#  (('the', 'lungs'), 190),
#  (('consolidation', 'No'), 113),
#  (('atelectasis', 'There'), 143),
#  (('size', 'of'), 123),
#  (('the', 'lower'), 151),
#  (('noted', 'The'), 126),
#  (('is', 'normal'), 283),
#  (('stable', 'The'), 115),
#  (('the', 'study'), 150),
#  (('is', 'likely'), 196),
#  (('unchanged', 'No'), 123),
#  (('the', 'lateral'), 231),
#  (('a', 'right'), 111),
#  (('seen', 'with'), 136),
#  (('are', 'no'), 308),
#  (('enlarged', 'and'), 141),
#  (('or', 'pulmonary'), 186),
#  (('is', 'new'), 109),
#  (('unchanged', 'with'), 112),
#  (('is', 'enlarged'), 303),
#  (('the', 'lung'), 312),
#  (('of', 'pulmonary'), 377),
#  (('of', 'atelectasis'), 138),
#  (('pneumothorax', 'There'), 239),
#  (('is', 'within'), 121),
#  (('and', 'right'), 323),
#  (('and', 'mild'), 153),
#  (('opacity', 'is'), 165),
#  (('No', 'pulmonary'), 180),
#  (('and', 'a'), 147),
#  (('is', 'increased'), 134),
#  (('congestion', 'There'), 101),
#  (('effusion', 'No'), 139),
#  (('The', 'lung'), 107),
#  (('is', 'moderate'), 158),
#  (('consolidation', 'There'), 117),
#  (('effusion', 'with'), 134),
#  (('The', 'left'), 148),
#  (('atelectasis', 'and'), 101),
#  (('congestion', 'is'), 238),
#  (('with', 'the'), 395),
#  (('consolidation', 'is'), 262),
#  (('effusion', 'There'), 181),
#  (('of', 'mild'), 107),
#  (('atelectasis', 'is'), 183),
#  (('of', 'pneumothorax'), 174),
#  (('effusion', 'is'), 403),
#  (('effusion', 'The'), 131),
#  (('edema', 'is'), 319),
#  (('The', 'right'), 131),
#  (('effusion', 'and'), 132),
#  (('The', 'pulmonary'), 110),
#  (('and', 'pulmonary'), 103),
#  (('the', 'pulmonary'), 186),
#  (('lung', 'is'), 105),
#  (('seen', 'is'), 107),
#  (('is', 'in'), 163),
#  (('and', 'the'), 198)]

# %%
finder = TrigramCollocationFinder.from_words(tokens)

# finder
# # # only bigrams that appear 3+ times
finder.apply_freq_filter(500)

# return the 10 n-grams with the highest PMI
trigrams = finder.nbest(trigram_measures.pmi, 100)
trigrams
# Out:
# [('acute', 'osseous', 'abnormalities'),
#  ('within', 'normal', 'limits'),
#  ('In', 'comparison', 'with'),
#  ('No', 'acute', 'osseous'),
#  ('As', 'compared', 'to'),
#  ('pulmonary', 'vascular', 'congestion'),
#  ('is', 'status', 'post'),
#  ('PA', 'and', 'lateral'),
#  ('Frontal', 'and', 'lateral'),
#  ('and', 'lateral', 'views'),
#  ('lateral', 'views', 'of'),
#  ('bilateral', 'pleural', 'effusions'),
#  ('and', 'hilar', 'contours'),
#  ('previous', 'radiograph', ','),
#  ('hilar', 'contours', 'are'),
#  ('.', 'In', 'comparison'),
#  ('patient', 'is', 'status'),
#  ('The', 'cardiomediastinal', 'silhouette'),
#  ('.', 'Bony', 'structures'),
#  ('lungs', 'are', 'clear'),
#  ('No', 'focal', 'consolidation'),
#  ('mediastinal', 'and', 'hilar'),
#  ('left', '-', 'sided'),
#  ('the', 'previous', 'radiograph'),
#  ('.', 'Lung', 'volumes'),
#  ('no', 'focal', 'consolidation'),
#  ('effusion', 'or', 'pneumothorax'),
#  ('The', 'cardiac', 'silhouette'),
#  ('Heart', 'size', 'is'),
#  ('right', '-', 'sided'),
#  ('.', 'As', 'compared'),
#  ('the', 'chest', 'were'),
#  ('study', 'of', '___'),
#  ('mild', 'pulmonary', 'edema'),
#  ('focal', 'consolidation', ','),
#  ('is', 'mildly', 'enlarged'),
#  ('pleural', 'effusion', 'or'),
#  ('.', 'Heart', 'size'),
#  ('contours', 'are', 'stable'),
#  ('cardiomediastinal', 'silhouette', 'is'),
#  ('right', 'atrium', 'and'),
#  ('no', 'evidence', 'of'),
#  ('the', 'cardiac', 'silhouette'),
#  ('The', 'lungs', 'are'),
#  ('.', 'Moderate', 'cardiomegaly'),
#  ('the', 'prior', 'study'),
#  ('compared', 'to', 'the'),
#  ('the', 'right', 'atrium'),
#  ('mildly', 'enlarged', '.'),
#  ('to', 'the', 'previous'),
#  ('cardiac', 'silhouette', 'is'),
#  ('-', 'to', '-'),
#  ('vascular', 'congestion', '.'),
#  ('no', 'pleural', 'effusion'),
#  ('views', 'of', 'the'),
#  ('There', 'is', 'no'),
#  ('left', 'pleural', 'effusion'),
#  ('is', 'no', 'evidence'),
#  ('pleural', 'effusions', 'are'),
#  ('No', 'pleural', 'effusion'),
#  ('enlargement', 'of', 'the'),
#  ('again', 'noted', '.'),
#  ('right', 'pleural', 'effusion'),
#  ('.', 'No', 'acute'),
#  ('there', 'is', 'no'),
#  ('The', 'patient', 'is'),
#  ('The', 'heart', 'is'),
#  ('consolidation', ',', 'pleural'),
#  ('prior', 'study', '.'),
#  ('of', 'the', 'chest'),
#  ('.', 'The', 'heart'),
#  ('.', 'Frontal', 'and'),
#  ('is', 'no', 'pneumothorax'),
#  ('.', 'The', 'cardiomediastinal'),
#  ('to', 'the', 'prior'),
#  ('is', 'no', 'focal'),
#  ('.', 'PA', 'and'),
#  ('right', 'ventricle', '.'),
#  ('pulmonary', 'edema', '.'),
#  (',', 'there', 'is'),
#  ('.', 'The', 'lungs'),
#  ('or', 'pneumothorax', '.'),
#  ('or', 'pneumothorax', 'is'),
#  ('There', 'is', 'mild'),
#  ('pneumothorax', 'is', 'seen'),
#  ('at', 'the', 'right'),
#  ('are', 'intact', '.'),
#  ('.', 'No', 'focal'),
#  ('.', 'The', 'patient'),
#  ('.', 'The', 'cardiac'),
#  ('of', '___', ','),
#  ('of', 'the', 'cardiac'),
#  ('are', 'unremarkable', '.'),
#  (',', 'pleural', 'effusion'),
#  ('There', 'is', 'a'),
#  ('.', 'The', 'aorta'),
#  ('in', 'the', 'right'),
#  ('There', 'are', 'no'),
#  ('pleural', 'effusion', ','),
#  ('pleural', 'effusions', '.')]

# %%
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_contingency',
#  '_expected_values',
#  '_marginals',
#  '_n',
#  'chi_sq',
#  'dice',
#  'fisher',
#  'jaccard',
#  'likelihood_ratio',
#  'mi_like',
#  'phi_sq',
#  'pmi',
#  'poisson_stirling',
#  'raw_freq',
#  'student_t']
